# %%
import numpy as np
import pandas as pd
import os
import shutil

# %%
path = "../raw_data/rois_aal_csv"
files = os.listdir(path)
file_name = []
for file in files:
    file_name.append(file[:-4])
file_name[0]
# Out:
# 'Caltech_0051456_rois_aal'

# %%
os.mkdir("../raw_data/rois_aal_csv_separate/Calthech")
os.mkdir("../raw_data/rois_aal_csv_separate/CMU_a")
os.mkdir("../raw_data/rois_aal_csv_separate/CMU_b")
os.mkdir("../raw_data/rois_aal_csv_separate/KKI")
os.mkdir("../raw_data/rois_aal_csv_separate/Leuven_1")
os.mkdir("../raw_data/rois_aal_csv_separate/Leuven_2")
os.mkdir("../raw_data/rois_aal_csv_separate/MaxMun_a")
os.mkdir("../raw_data/rois_aal_csv_separate/MaxMun_b")
os.mkdir("../raw_data/rois_aal_csv_separate/MaxMun_c")
os.mkdir("../raw_data/rois_aal_csv_separate/MaxMun_d")
os.mkdir("../raw_data/rois_aal_csv_separate/NYU")
os.mkdir("../raw_data/rois_aal_csv_separate/OHSU")
os.mkdir("../raw_data/rois_aal_csv_separate/Olin")
os.mkdir("../raw_data/rois_aal_csv_separate/Pitt")
os.mkdir("../raw_data/rois_aal_csv_separate/SBL")
os.mkdir("../raw_data/rois_aal_csv_separate/SDSU")
os.mkdir("../raw_data/rois_aal_csv_separate/Stanford")
os.mkdir("../raw_data/rois_aal_csv_separate/Trinity")
os.mkdir("../raw_data/rois_aal_csv_separate/UCLA_1")
os.mkdir("../raw_data/rois_aal_csv_separate/UCLA_2")
os.mkdir("../raw_data/rois_aal_csv_separate/UM_1")
os.mkdir("../raw_data/rois_aal_csv_separate/UM_2")
os.mkdir("../raw_data/rois_aal_csv_separate/USM")
os.mkdir("../raw_data/rois_aal_csv_separate/Yale")

# %%
Caltech = []
CMU_a = []
CMU_b = []
KKI = []
Leuven_1 = []
Leuven_2 = []
MaxMun_a = []
MaxMun_b = []
MaxMun_c = []
MaxMun_d = []
NYU = []
OHSU = []
Olin = []
Pitt = []
SBL = []
SDSU = []
Stanford = []
Trinity = []
UCLA_1 = []
UCLA_2 = []
UM_1 = []
UM_2 = []
USM = []
Yale = []
error = 0
for file in file_name:
    path_before = f"D:\\Grade_3.1\\基于自注意力机制的自闭症判别\\ASD_SelfAttention\\raw_data\\rois_aal_csv\\{file}.csv"
    if file[:2] == "Ca":
        Caltech.append(file)
        path_after = f"D:\\Grade_3.1\\基于自注意力机制的自闭症判别\\ASD_SelfAttention\\raw_data\\rois_aal_csv_separate\\Calthech\\{file}.csv"
        shutil.copy(path_before,path_after)
    elif file[:2] == "CM":
        if file[:5] == "CMU_a":
            CMU_a.append(file)
            path_after = f"D:\\Grade_3.1\\基于自注意力机制的自闭症判别\\ASD_SelfAttention\\raw_data\\rois_aal_csv_separate\\CMU_a\\{file}.csv"
            shutil.copy(path_before,path_after)
        elif file[:5] == "CMU_b":
            CMU_b.append(file)
            path_after = f"D:\\Grade_3.1\\基于自注意力机制的自闭症判别\\ASD_SelfAttention\\raw_data\\rois_aal_csv_separate\\CMU_b\\{file}.csv"
            shutil.copy(path_before,path_after)
    elif file[:2] == "KK":
        KKI.append(file)
        path_after = f"D:\\Grade_3.1\\基于自注意力机制的自闭症判别\\ASD_SelfAttention\\raw_data\\rois_aal_csv_separate\\KKI\\{file}.csv"
        shutil.copy(path_before,path_after)
    elif file[:2] == "Le":
        if file[:8] == "Leuven_1":
            Leuven_1.append(file)
            path_after = f"D:\\Grade_3.1\\基于自注意力机制的自闭症判别\\ASD_SelfAttention\\raw_data\\rois_aal_csv_separate\\Leuven_1\\{file}.csv"
            shutil.copy(path_before,path_after)
        elif file[:8] == "Leuven_2":
            Leuven_2.append(file)
            path_after = f"D:\\Grade_3.1\\基于自注意力机制的自闭症判别\\ASD_SelfAttention\\raw_data\\rois_aal_csv_separate\\Leuven_2\\{file}.csv"
            shutil.copy(path_before,path_after)
    elif file[:2] == "Ma":
        if file[:8] == "MaxMun_a":
            MaxMun_a.append(file)
            path_after = f"D:\\Grade_3.1\\基于自注意力机制的自闭症判别\\ASD_SelfAttention\\raw_data\\rois_aal_csv_separate\\MaxMun_a\\{file}.csv"
            shutil.copy(path_before,path_after)
        elif file[:8] == "MaxMun_b":
            MaxMun_b.append(file)
            path_after = f"D:\\Grade_3.1\\基于自注意力机制的自闭症判别\\ASD_SelfAttention\\raw_data\\rois_aal_csv_separate\\MaxMun_b\\{file}.csv"
            shutil.copy(path_before,path_after)
        elif file[:8] == "MaxMun_c":
            MaxMun_c.append(file)
            path_after = f"D:\\Grade_3.1\\基于自注意力机制的自闭症判别\\ASD_SelfAttention\\raw_data\\rois_aal_csv_separate\\MaxMun_c\\{file}.csv"
            shutil.copy(path_before,path_after)
        elif file[:8] == "MaxMun_d":
            MaxMun_d.append(file)
            path_after = f"D:\\Grade_3.1\\基于自注意力机制的自闭症判别\\ASD_SelfAttention\\raw_data\\rois_aal_csv_separate\\MaxMun_d\\{file}.csv"
            shutil.copy(path_before,path_after)
    elif file[:2] == "NY":
        NYU.append(file)
        path_after = f"D:\\Grade_3.1\\基于自注意力机制的自闭症判别\\ASD_SelfAttention\\raw_data\\rois_aal_csv_separate\\NYU\\{file}.csv"
        shutil.copy(path_before,path_after)
    elif file[:2] == "OH":
        OHSU.append(file)
        path_after = f"D:\\Grade_3.1\\基于自注意力机制的自闭症判别\\ASD_SelfAttention\\raw_data\\rois_aal_csv_separate\\OHSU\\{file}.csv"
        shutil.copy(path_before,path_after)
    elif file[:2] == "Ol":
        Olin.append(file)
        path_after = f"D:\\Grade_3.1\\基于自注意力机制的自闭症判别\\ASD_SelfAttention\\raw_data\\rois_aal_csv_separate\\Olin\\{file}.csv"
        shutil.copy(path_before,path_after)
    elif file[:2] == "Pi":
        Pitt.append(file)
        path_after = f"D:\\Grade_3.1\\基于自注意力机制的自闭症判别\\ASD_SelfAttention\\raw_data\\rois_aal_csv_separate\\Pitt\\{file}.csv"
        shutil.copy(path_before,path_after)
    elif file[:2] == "SB":
        SBL.append(file)
        path_after = f"D:\\Grade_3.1\\基于自注意力机制的自闭症判别\\ASD_SelfAttention\\raw_data\\rois_aal_csv_separate\\SBL\\{file}.csv"
        shutil.copy(path_before,path_after)
    elif file[:2] == "SD":
        SDSU.append(file)
        path_after = f"D:\\Grade_3.1\\基于自注意力机制的自闭症判别\\ASD_SelfAttention\\raw_data\\rois_aal_csv_separate\\SDSU\\{file}.csv"
        shutil.copy(path_before,path_after)
    elif file[:2] == "St":
        Stanford.append(file)
        path_after = f"D:\\Grade_3.1\\基于自注意力机制的自闭症判别\\ASD_SelfAttention\\raw_data\\rois_aal_csv_separate\\Stanford\\{file}.csv"
        shutil.copy(path_before,path_after)
    elif file[:2] == "Tr":
        Trinity.append(file)
        path_after = f"D:\\Grade_3.1\\基于自注意力机制的自闭症判别\\ASD_SelfAttention\\raw_data\\rois_aal_csv_separate\\Trinity\\{file}.csv"
        shutil.copy(path_before,path_after)
    elif file[:2] == "UC":
        if file[:6] == "UCLA_1":
            UCLA_1.append(file)
            path_after = f"D:\\Grade_3.1\\基于自注意力机制的自闭症判别\\ASD_SelfAttention\\raw_data\\rois_aal_csv_separate\\UCLA_1\\{file}.csv"
            shutil.copy(path_before,path_after)
        elif file[:6] == "UCLA_2":
            UCLA_2.append(file)
            path_after = f"D:\\Grade_3.1\\基于自注意力机制的自闭症判别\\ASD_SelfAttention\\raw_data\\rois_aal_csv_separate\\UCLA_2\\{file}.csv"
            shutil.copy(path_before,path_after)
    elif file[:2] == "UM":
        if file[:4] == "UM_1":
            UM_1.append(file)
            path_after = f"D:\\Grade_3.1\\基于自注意力机制的自闭症判别\\ASD_SelfAttention\\raw_data\\rois_aal_csv_separate\\UM_1\\{file}.csv"
            shutil.copy(path_before,path_after)
        elif file[:4] == "UM_2":
            UM_2.append(file)
            path_after = f"D:\\Grade_3.1\\基于自注意力机制的自闭症判别\\ASD_SelfAttention\\raw_data\\rois_aal_csv_separate\\UM_2\\{file}.csv"
            shutil.copy(path_before,path_after)
    elif file[:2] == "US":
        USM.append(file)
        path_after = f"D:\\Grade_3.1\\基于自注意力机制的自闭症判别\\ASD_SelfAttention\\raw_data\\rois_aal_csv_separate\\USM\\{file}.csv"
        shutil.copy(path_before,path_after)
    elif file[:2] == "Ya":
        Yale.append(file)
        path_after = f"D:\\Grade_3.1\\基于自注意力机制的自闭症判别\\ASD_SelfAttention\\raw_data\\rois_aal_csv_separate\\Yale\\{file}.csv"
        shutil.copy(path_before,path_after)
    else:
        error+=1
error
# Out:
# 0

# %%
path_before = "../raw_data/rois_aal_csv"
