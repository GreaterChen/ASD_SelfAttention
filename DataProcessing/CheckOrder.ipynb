# %%
import numpy as np
import pandas as pd
import os 
import re

# %%
label = pd.read_csv("../description/label.csv")["SUB_ID"]
label
# Out:
# 0      51456
# 1      51457
# 2      51458
# 3      51459
# 4      51460
#        ...
# 879    50624
# 880    50625
# 881    50626
# 882    50627
# 883    50628
# Name: SUB_ID, Length: 884, dtype: int64

# %%
label = label.to_list()
label
# Out:
# [51456,
#  51457,
#  51458,
#  51459,
#  51460,
#  51461,
#  51462,
#  51463,
#  51464,
#  51465,
#  51466,
#  51467,
#  51468,
#  51469,
#  51470,
#  51471,
#  51472,
#  51473,
#  51474,
#  51476,
#  51477,
#  51478,
#  51479,
#  51480,
#  51481,
#  51482,
#  51483,
#  51484,
#  51485,
#  51486,
#  51487,
#  51488,
#  51489,
#  51490,
#  51491,
#  51492,
#  51493,
#  50649,
#  50653,
#  50651,
#  50657,
#  50669,
#  50772,
#  50773,
#  50774,
#  50775,
#  50776,
#  50777,
#  50778,
#  50779,
#  50780,
#  50781,
#  50782,
#  50783,
#  50785,
#  50786,
#  50787,
#  50788,
#  50789,
#  50790,
#  50791,
#  50792,
#  50795,
#  50798,
#  50799,
#  50800,
#  50802,
#  50803,
#  50804,
#  50812,
#  50814,
#  50816,
#  50817,
#  50818,
#  50819,
#  50820,
#  50821,
#  50822,
#  50823,
#  50824,
#  50825,
#  50682,
#  50683,
#  50685,
#  50686,
#  50687,
#  50688,
#  50689,
#  50690,
#  50691,
#  50692,
#  50693,
#  50694,
#  50695,
#  50696,
#  50697,
#  50698,
#  50699,
#  50700,
#  50701,
# ...

# %%
files = os.listdir("../raw_data/rois_aal_csv")
files
# Out:
# ['Caltech_0051456_rois_aal.csv',
#  'Caltech_0051457_rois_aal.csv',
#  'Caltech_0051458_rois_aal.csv',
#  'Caltech_0051459_rois_aal.csv',
#  'Caltech_0051460_rois_aal.csv',
#  'Caltech_0051461_rois_aal.csv',
#  'Caltech_0051462_rois_aal.csv',
#  'Caltech_0051463_rois_aal.csv',
#  'Caltech_0051464_rois_aal.csv',
#  'Caltech_0051465_rois_aal.csv',
#  'Caltech_0051466_rois_aal.csv',
#  'Caltech_0051467_rois_aal.csv',
#  'Caltech_0051468_rois_aal.csv',
#  'Caltech_0051469_rois_aal.csv',
#  'Caltech_0051470_rois_aal.csv',
#  'Caltech_0051471_rois_aal.csv',
#  'Caltech_0051472_rois_aal.csv',
#  'Caltech_0051473_rois_aal.csv',
#  'Caltech_0051474_rois_aal.csv',
#  'Caltech_0051476_rois_aal.csv',
#  'Caltech_0051477_rois_aal.csv',
#  'Caltech_0051478_rois_aal.csv',
#  'Caltech_0051479_rois_aal.csv',
#  'Caltech_0051480_rois_aal.csv',
#  'Caltech_0051481_rois_aal.csv',
#  'Caltech_0051482_rois_aal.csv',
#  'Caltech_0051483_rois_aal.csv',
#  'Caltech_0051484_rois_aal.csv',
# ...

# %%
error = 0
for i in range(884):
    id = label[i]
    file_name = files[i]
    if re.search(str(id),file_name) == None:
        print(id,file_name)
        error +=1
error
# Out:
# 0
